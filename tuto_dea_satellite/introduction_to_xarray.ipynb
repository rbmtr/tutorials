# %%
import xarray as xr
from datetime import datetime
from matplotlib import pyplot as plt

# %%
ds = xr.open_dataset('data/canberra_ls8.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 5MB
# Dimensions:    (time: 2, latitude: 320, longitude: 320)
# Coordinates:
#   * time       (time) datetime64[ns] 16B 2016-01-01 2017-01-01
#   * latitude   (latitude) float64 3kB -35.34 -35.34 -35.34 ... -35.26 -35.26
#   * longitude  (longitude) float64 3kB 149.1 149.1 149.1 ... 149.2 149.2 149.2
# Data variables:
#     crs        int32 4B ...
#     blue       (time, latitude, longitude) float32 819kB ...
#     green      (time, latitude, longitude) float32 819kB ...
#     red        (time, latitude, longitude) float32 819kB ...
#     nir        (time, latitude, longitude) float32 819kB ...
#     swir1      (time, latitude, longitude) float32 819kB ...
#     swir2      (time, latitude, longitude) float32 819kB ...
# Attributes:
#     date_created:           2019-10-18T11:27:53.613700
#     Conventions:            CF-1.6, ACDD-1.3
#     history:                NetCDF-CF file created by datacube version '1.7+1...
# ...

# %%
ds.green
# Out:
# <xarray.DataArray 'green' (time: 2, latitude: 320, longitude: 320)> Size: 819kB
# [204800 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 16B 2016-01-01 2017-01-01
#   * latitude   (latitude) float64 3kB -35.34 -35.34 -35.34 ... -35.26 -35.26
#   * longitude  (longitude) float64 3kB 149.1 149.1 149.1 ... 149.2 149.2 149.2
# Attributes:
#     grid_mapping:  crs
#     units:         1

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 2)> Size: 16B
# array(['2016-01-01T00:00:00.000000000', '2017-01-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 16B 2016-01-01 2017-01-01
# Attributes:
#     standard_name:  time
#     long_name:      Time, unix time-stamp
#     axis:           T

# %%
ds.Conventions
# Out:
# 'CF-1.6, ACDD-1.3'

# %%
ds.geospatial_bounds_crs
# Out:
# 'EPSG:4326'

# %%
ds.longitude.values
# Out:
# array([149.080125, 149.080375, 149.080625, 149.080875, 149.081125,
#        149.081375, 149.081625, 149.081875, 149.082125, 149.082375,
#        149.082625, 149.082875, 149.083125, 149.083375, 149.083625,
#        149.083875, 149.084125, 149.084375, 149.084625, 149.084875,
#        149.085125, 149.085375, 149.085625, 149.085875, 149.086125,
#        149.086375, 149.086625, 149.086875, 149.087125, 149.087375,
#        149.087625, 149.087875, 149.088125, 149.088375, 149.088625,
#        149.088875, 149.089125, 149.089375, 149.089625, 149.089875,
#        149.090125, 149.090375, 149.090625, 149.090875, 149.091125,
#        149.091375, 149.091625, 149.091875, 149.092125, 149.092375,
#        149.092625, 149.092875, 149.093125, 149.093375, 149.093625,
#        149.093875, 149.094125, 149.094375, 149.094625, 149.094875,
#        149.095125, 149.095375, 149.095625, 149.095875, 149.096125,
#        149.096375, 149.096625, 149.096875, 149.097125, 149.097375,
# ...

# %%
ds.green.isel(time=0)
# Out:
# <xarray.DataArray 'green' (latitude: 320, longitude: 320)> Size: 410kB
# [102400 values with dtype=float32]
# Coordinates:
#     time       datetime64[ns] 8B 2016-01-01
#   * latitude   (latitude) float64 3kB -35.34 -35.34 -35.34 ... -35.26 -35.26
#   * longitude  (longitude) float64 3kB 149.1 149.1 149.1 ... 149.2 149.2 149.2
# Attributes:
#     grid_mapping:  crs
#     units:         1

# %%
ds.green.sel(time=datetime(2016,1,1))
# Out:
# <xarray.DataArray 'green' (latitude: 320, longitude: 320)> Size: 410kB
# [102400 values with dtype=float32]
# Coordinates:
#     time       datetime64[ns] 8B 2016-01-01
#   * latitude   (latitude) float64 3kB -35.34 -35.34 -35.34 ... -35.26 -35.26
#   * longitude  (longitude) float64 3kB 149.1 149.1 149.1 ... 149.2 149.2 149.2
# Attributes:
#     grid_mapping:  crs
#     units:         1

# %%
ds.green.sel(time=datetime(2016,1,1), latitude=slice(-35.30,-35.24))
# Out:
# <xarray.DataArray 'green' (latitude: 160, longitude: 320)> Size: 205kB
# [51200 values with dtype=float32]
# Coordinates:
#     time       datetime64[ns] 8B 2016-01-01
#   * latitude   (latitude) float64 1kB -35.3 -35.3 -35.3 ... -35.26 -35.26 -35.26
#   * longitude  (longitude) float64 3kB 149.1 149.1 149.1 ... 149.2 149.2 149.2
# Attributes:
#     grid_mapping:  crs
#     units:         1

# %%
ds.red.sel(longitude=slice(149.11,149.13), latitude=slice(-35.30,-35.29))
# Out:
# <xarray.DataArray 'red' (time: 2, latitude: 40, longitude: 80)> Size: 26kB
# [6400 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 16B 2016-01-01 2017-01-01
#   * latitude   (latitude) float64 320B -35.3 -35.3 -35.3 ... -35.29 -35.29
#   * longitude  (longitude) float64 640B 149.1 149.1 149.1 ... 149.1 149.1 149.1
# Attributes:
#     grid_mapping:  crs
#     units:         1

# %%
plt.imshow(ds.red.isel(time=0).values)

# %%
ds.red.mean() - ds.nir.mean()
# Out:
# <xarray.DataArray ()> Size: 4B
# array(-1439.5886, dtype=float32)

# %%
to_plot = ds[["red", "green", "blue"]].sel(time=datetime(2017,1,1), latitude=slice(-35.29, -35.27),longitude=slice(149.1, 149.13))

# %%
type(to_plot)
# Out:
# xarray.core.dataset.Dataset

# %%
to_plot.to_array().plot.imshow(robust=True, figsize=(6, 6))

# %%
((ds.nir-ds.red)/(ds.nir+ds.red)).isel(time=0).plot(figsize=(6, 6), cmap='summer_r')
